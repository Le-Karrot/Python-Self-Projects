# %% [markdown]
# basic utilization for program:
#
# data container maybe a list, set, dictionaries
#
# iterations to retreive/update data
#
# display to user:
#
# begin with a menu and output results till user exits or exception handling occurs
#
# results from all functions
#
# program structure-
#
# checkout function:
# trying a dictionary where a nested loop hold category - {"item zone" : { "item catagory: {"item name": "price"}}}
#
# *could also use a class for items structure*
#
# take input and validate string input
#
# retreive value from dictionary
#
# output result
#
# inventory management:
